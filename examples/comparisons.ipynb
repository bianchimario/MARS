# %%
pip uninstall MARS --y
# Out:
# Found existing installation: MARS 1.0.0
# Uninstalling MARS-1.0.0:
#   Successfully uninstalled MARS-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/bianchimario/MARS
# Out:
# ...
#   Cloning https://github.com/bianchimario/MARS to /private/var/folders/kj/2bfwcpp56ljb52n904gv1_700000gn/T/pip-req-build-tt31z9qx
#   Running command git clone --filter=blob:none --quiet https://github.com/bianchimario/MARS /private/var/folders/kj/2bfwcpp56ljb52n904gv1_700000gn/T/pip-req-build-tt31z9qx
#   Resolved https://github.com/bianchimario/MARS to commit 9277e402404d6df93cca88b951106cc979aae387
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for MARS: filename=MARS-1.0.0-py3-none-any.whl size=14633 sha256=9ee225ac6771dca37a0480e384db2b1c15f07aef3139e53cd36d05d33ff183e6
#   Stored in directory: /private/var/folders/kj/2bfwcpp56ljb52n904gv1_700000gn/T/pip-ephem-wheel-cache-_mbpxdhe/wheels/7c/54/7a/9a1b3a604937feb86544be13c30bf12c1ee3b43b898c4a6af9
# Successfully built MARS
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from downtime import load_dataset
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.metrics import classification_report
from MARS import *
import numpy as np
from datatime.conversion import awkward_to_flat

# %% [markdown]
# # SelfRegulationSCP1

# %%
d = load_dataset("SelfRegulationSCP1")

X_train = d.X_train
X_test = d.X_test
y_train = d.y_train
y_test = d.y_test

# %%
print(d)
# Out:
# X_train: (5890, 144, 62)
# X_test: (3524, 144, 62)
# y_train: (5890,)
# y_test: (3524,)
# Metadata:
# {'labels': {'0': '0', '1': '1'},
#  'name': 'FaceDetection',
#  'task': 'classification'}

# %% [markdown]
# ## Multivariate Shapelets

# %%
shapelets = get_random_shapelets(X_train, num_shapelets=20, max_len=100, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(X_train, shapelets)

X_test_transformed = transform(X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.61      0.72       147
#            1       0.70      0.91      0.79       146
#
#     accuracy                           0.76       293
#    macro avg       0.79      0.76      0.76       293
# weighted avg       0.79      0.76      0.76       293

# %% [markdown]
# ## Univariate Shapelets

# %%
flat_X_train = awkward_to_flat(X_train).to_numpy()
flat_X_test = awkward_to_flat(X_test).to_numpy()

# %%
# Putting each value inside a list

flat_X_train = [[x] for x in flat_X_train]
flat_X_test = [[x] for x in flat_X_test]

# %%
shapelets = get_random_shapelets(flat_X_train, num_shapelets=20, max_len=100, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(flat_X_train, shapelets)

X_test_transformed = transform(flat_X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.52      0.64       147
#            1       0.65      0.91      0.76       146
#
#     accuracy                           0.71       293
#    macro avg       0.75      0.71      0.70       293
# weighted avg       0.75      0.71      0.70       293

# %% [markdown]
# # FaceDetection

# %%
d = load_dataset("FaceDetection")

X_train = d.X_train
X_test = d.X_test
y_train = d.y_train
y_test = d.y_test
# Out:
# 9064it [01:36, 94.23it/s]
# 15146it [02:47, 90.56it/s]
# 1it [00:00, 1757.14it/s]
# 1it [00:00, 1283.84it/s]
# 1it [00:00, 471.01it/s]

# %%
print(d)
# Out:
# X_train: (5890, 144, 62)
# X_test: (3524, 144, 62)
# y_train: (5890,)
# y_test: (3524,)
# Metadata:
# {'labels': {'0': '0', '1': '1'},
#  'name': 'FaceDetection',
#  'task': 'classification'}

# %% [markdown]
# ## MultivariateShapelets

# %%
shapelets = get_random_shapelets(X_train, num_shapelets=20, max_len=60, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(X_train, shapelets)

X_test_transformed = transform(X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)
# Out:
# Calculating distances for TS # 0
# Calculating distances for TS # 1
# Calculating distances for TS # 2
# Calculating distances for TS # 3
# Calculating distances for TS # 4
# Calculating distances for TS # 5
# Calculating distances for TS # 6
# Calculating distances for TS # 7
# Calculating distances for TS # 8
# Calculating distances for TS # 9
# Calculating distances for TS # 10
# Calculating distances for TS # 11
# Calculating distances for TS # 12
# Calculating distances for TS # 13
# Calculating distances for TS # 14
# Calculating distances for TS # 15
# Calculating distances for TS # 16
# Calculating distances for TS # 17
# Calculating distances for TS # 18
# Calculating distances for TS # 19
# Calculating distances for TS # 20
# Calculating distances for TS # 21
# Calculating distances for TS # 22
# Calculating distances for TS # 23
# Calculating distances for TS # 24
# Calculating distances for TS # 25
# Calculating distances for TS # 26
# Calculating distances for TS # 27
# ...

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.49      0.51      1762
#            1       0.52      0.56      0.54      1762
#
#     accuracy                           0.52      3524
#    macro avg       0.53      0.52      0.52      3524
# weighted avg       0.53      0.52      0.52      3524

# %% [markdown]
# ## Univariate Shapelets

# %%
flat_X_train = awkward_to_flat(X_train).to_numpy()
flat_X_test = awkward_to_flat(X_test).to_numpy()

# %%
# Putting each value inside a list

flat_X_train = [[x] for x in flat_X_train]
flat_X_test = [[x] for x in flat_X_test]

# %%
shapelets = get_random_shapelets(flat_X_train, num_shapelets=20, max_len=60, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(flat_X_train, shapelets)

X_test_transformed = transform(flat_X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)
# Out:
# Calculating distances for TS # 0
# Calculating distances for TS # 1
# Calculating distances for TS # 2
# Calculating distances for TS # 3
# Calculating distances for TS # 4
# Calculating distances for TS # 5
# Calculating distances for TS # 6
# Calculating distances for TS # 7
# Calculating distances for TS # 8
# Calculating distances for TS # 9
# Calculating distances for TS # 10
# Calculating distances for TS # 11
# Calculating distances for TS # 12
# Calculating distances for TS # 13
# Calculating distances for TS # 14
# Calculating distances for TS # 15
# Calculating distances for TS # 16
# Calculating distances for TS # 17
# Calculating distances for TS # 18
# Calculating distances for TS # 19
# Calculating distances for TS # 20
# Calculating distances for TS # 21
# Calculating distances for TS # 22
# Calculating distances for TS # 23
# Calculating distances for TS # 24
# Calculating distances for TS # 25
# Calculating distances for TS # 26
# Calculating distances for TS # 27
# ...

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.45      0.47      1762
#            1       0.50      0.55      0.52      1762
#
#     accuracy                           0.50      3524
#    macro avg       0.50      0.50      0.50      3524
# weighted avg       0.50      0.50      0.50      3524

# %% [markdown]
# # Hearbeat

# %%
d = load_dataset("Heartbeat")

X_train = d.X_train
X_test = d.X_test
y_train = d.y_train
y_test = d.y_test
# Out:
# 1359it [00:06, 222.47it/s]
# 1352it [00:06, 198.11it/s]
# 1it [00:00, 3004.52it/s]
# 1it [00:00, 1630.76it/s]
# 1it [00:00, 3059.30it/s]

# %%
print(d)
# Out:
# X_train: (204, 61, 405)
# X_test: (205, 61, 405)
# y_train: (204,)
# y_test: (205,)
# Metadata:
# {'labels': {'0': 'abnormal', '1': 'normal'},
#  'name': 'Heartbeat',
#  'task': 'classification'}

# %% [markdown]
# ## Multivariate Shapelet

# %%
shapelets = get_random_shapelets(X_train, num_shapelets=20, max_len=60, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(X_train, shapelets)

X_test_transformed = transform(X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)
# Out:
# Calculating distances for TS # 0
# Calculating distances for TS # 1
# Calculating distances for TS # 2
# Calculating distances for TS # 3
# Calculating distances for TS # 4
# Calculating distances for TS # 5
# Calculating distances for TS # 6
# Calculating distances for TS # 7
# Calculating distances for TS # 8
# Calculating distances for TS # 9
# Calculating distances for TS # 10
# Calculating distances for TS # 11
# Calculating distances for TS # 12
# Calculating distances for TS # 13
# Calculating distances for TS # 14
# Calculating distances for TS # 15
# Calculating distances for TS # 16
# Calculating distances for TS # 17
# Calculating distances for TS # 18
# Calculating distances for TS # 19
# Calculating distances for TS # 20
# Calculating distances for TS # 21
# Calculating distances for TS # 22
# Calculating distances for TS # 23
# Calculating distances for TS # 24
# Calculating distances for TS # 25
# Calculating distances for TS # 26
# Calculating distances for TS # 27
# ...

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81       148
#            1       0.46      0.33      0.39        57
#
#     accuracy                           0.71       205
#    macro avg       0.62      0.59      0.60       205
# weighted avg       0.68      0.71      0.69       205

# %% [markdown]
# ## Univariate Shapelet

# %%
flat_X_train = awkward_to_flat(X_train).to_numpy()
flat_X_test = awkward_to_flat(X_test).to_numpy()

# %%
# Putting each value inside a list

flat_X_train = [[x] for x in flat_X_train]
flat_X_test = [[x] for x in flat_X_test]

# %%
shapelets = get_random_shapelets(flat_X_train, num_shapelets=20, max_len=60, min_len=20, async_shapelets=False, seed=42)

# %%
X_train_transformed = transform(flat_X_train, shapelets)

X_test_transformed = transform(flat_X_test, shapelets)

clf = lgb.LGBMClassifier()
clf.fit(X_train_transformed, y_train)
# Out:
# Calculating distances for TS # 0
# Calculating distances for TS # 1
# Calculating distances for TS # 2
# Calculating distances for TS # 3
# Calculating distances for TS # 4
# Calculating distances for TS # 5
# Calculating distances for TS # 6
# Calculating distances for TS # 7
# Calculating distances for TS # 8
# Calculating distances for TS # 9
# Calculating distances for TS # 10
# Calculating distances for TS # 11
# Calculating distances for TS # 12
# Calculating distances for TS # 13
# Calculating distances for TS # 14
# Calculating distances for TS # 15
# Calculating distances for TS # 16
# Calculating distances for TS # 17
# Calculating distances for TS # 18
# Calculating distances for TS # 19
# Calculating distances for TS # 20
# Calculating distances for TS # 21
# Calculating distances for TS # 22
# Calculating distances for TS # 23
# Calculating distances for TS # 24
# Calculating distances for TS # 25
# Calculating distances for TS # 26
# Calculating distances for TS # 27
# ...

# %%
y_pred_test = clf.predict(X_test_transformed)

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81       148
#            1       0.44      0.28      0.34        57
#
#     accuracy                           0.70       205
#    macro avg       0.60      0.57      0.58       205
# weighted avg       0.67      0.70      0.68       205
